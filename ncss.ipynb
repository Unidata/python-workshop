# %% [markdown]
# # Exploring THREDDS netCDF Subset Service (NCSS) with Pandas
# - NCSS is a web service for subsetting CDM scientific datasets.
# - NCSS can return CSV format which works well with Pandas.
#
# ## Pandas
# - Pandas is a highly popular data analysis library for Python (think, R, SQL, Excel, etc.).
# - Built on top of Numpy
#
# ## Let's explore some Short Range Ensemble Forecast (SREF) data from the TDS
# - Build the NCSS URL parameters.
# - Request CSV data
# - Read data into a "Pandas DataFrame" object

# %%
import urllib
import datetime as dt
import string
import pandas as pd
# base THREDDS URL from which we will request our data
ncss_url = "http://thredds.ucar.edu/thredds/ncss/grid/grib/NCEP/SREF/CONUS_40km/ensprod_biasc/collection"

# Forming our date range
start_time = dt.datetime.utcnow() - dt.timedelta(hours = 12)

# Construct the URL parameters requesting CSV point data
parameters = (('var', 'Temperature_height_above_ground_weightedMean'), 
     ('var', 'Temperature_height_above_ground_stdDev'), 
     ('latitude', 40.044385),
     ('longitude', -105.21928),
     ('time_start', start_time.strftime("%Y-%m-%dT%H")),
     ('time_duration', 'P3DT12H'),
     ('accept','csv'),
     ('point', 'true'))

# prepping the URL parameters
params = urllib.urlencode(parameters)

# join the base URL with the parameters
url = string.join([ncss_url, params], '?')
print("Our fully constructed URL...\n")
print(url)
# Out:
# Our fully constructed URL...
#
# http://thredds.ucar.edu/thredds/ncss/grid/grib/NCEP/SREF/CONUS_40km/ensprod_biasc/collection?var=Temperature_height_above_ground_weightedMean&var=Temperature_height_above_ground_stdDev&latitude=40.044385&longitude=-105.21928&time_start=2013-07-19T08&time_duration=P3DT12H&accept=csv&point=true

# %% [markdown]
# ## Pandas DataFrame
# - A spreadsheet-like data structure

# %%
# This cell continued from previous Python cell

# Reading remote data into a pandas data frame
# The first argument is the URL we constructed above.
# Subsequent arguments below deal with parsing the date time
# Indexing with datetime
df  = pd.read_csv(url,  parse_dates={'datetime':['date']}, date_parser=
    lambda x: dt.datetime.strptime( x, '%Y-%m-%dT%H:%M:%SZ'), index_col='datetime')

# Constructing a time series with time as the index, and associating temperature
# and temperature STDV to that index
temps = df.ix[:, [3,4]]
print(temps.head())
# Out:
#                      Temperature_height_above_ground_weightedMean[unit="K"]  \
# datetime
# 2013-07-19 09:00:00                                         294.410004
# 2013-07-19 12:00:00                                         291.239990
# 2013-07-19 15:00:00                                         291.739990
# 2013-07-19 18:00:00                                         297.480011
# 2013-07-19 21:00:00                                         298.170013
#
#                      Temperature_height_above_ground_stdDev[unit="K"]
# datetime
# 2013-07-19 09:00:00                                               1.0
# 2013-07-19 12:00:00                                               1.1
# 2013-07-19 15:00:00                                               2.3
# 2013-07-19 18:00:00                                               2.1
# 2013-07-19 21:00:00                                               2.0

# %% [markdown]
# ## Let's make the columns nicer.

# %%
# Renaming columns to something more convenient
temps.columns = ['T (K)', 'T STDV (K)']
# Let's localize the time zone for good measure
temps = temps.tz_localize('UTC')
# Printing only the top of the data frame
temps.head()
# Out:
#                                 T (K)  T STDV (K)
# datetime
# 2013-07-19 09:00:00+00:00  294.410004         1.0
# 2013-07-19 12:00:00+00:00  291.239990         1.1
# 2013-07-19 15:00:00+00:00  291.739990         2.3
# 2013-07-19 18:00:00+00:00  293.369995         3.2
# 2013-07-19 21:00:00+00:00  296.209991         3.1

# %% [markdown]
# ## Let's prepare the data for plotting

# %%
# Calculate the high and low standard deviation
temps['Lo STDV (K)'] = temps['T (K)'] - temps['T STDV (K)']
temps['Hi STDV (K)'] = temps['T (K)'] + temps['T STDV (K)']

# Pandas dataframes are *mutable*, therefore deep copy
temps2 = temps.copy()

# Getting rid of stdv column to make things simpler below 
del temps2['T STDV (K)']
temps2.head()
# Out:
#                                 T (K)  Lo STDV (K)  Hi STDV (K)
# datetime
# 2013-07-19 09:00:00+00:00  294.410004   293.410004   295.410004
# 2013-07-19 12:00:00+00:00  291.239990   290.139990   292.339990
# 2013-07-19 15:00:00+00:00  291.739990   289.439990   294.039990
# 2013-07-19 18:00:00+00:00  293.369995   290.169995   296.569995
# 2013-07-19 21:00:00+00:00  296.209991   293.109992   299.309991

# %% [markdown]
# ## Let's resample the data to one hourly data

# %%
# First convert to 1 hourly data
temps3 = temps2.asfreq('1H')
print(temps3.head())
# Apply interpolation function to converted data
temps3 = temps3.apply(pd.Series.interpolate)
temps3.head()
# Out:
#                                 T (K)  Lo STDV (K)  Hi STDV (K)
# 2013-07-19 09:00:00+00:00  294.410004   293.410004   295.410004
# 2013-07-19 10:00:00+00:00         NaN          NaN          NaN
# 2013-07-19 11:00:00+00:00         NaN          NaN          NaN
# 2013-07-19 12:00:00+00:00  291.239990   290.139990   292.339990
# 2013-07-19 13:00:00+00:00         NaN          NaN          NaN
#                                 T (K)  Lo STDV (K)  Hi STDV (K)
# 2013-07-19 09:00:00+00:00  294.410004   293.410004   295.410004
# 2013-07-19 10:00:00+00:00  293.353333   292.319999   294.386666
# 2013-07-19 11:00:00+00:00  292.296661   291.229995   293.363328
# 2013-07-19 12:00:00+00:00  291.239990   290.139990   292.339990
# 2013-07-19 13:00:00+00:00  291.406657   289.906657   292.906657

# %% [markdown]
# ## Convert from Kelvin to Fahrenheit
# - Remember to change the units in the column names.

# %%
convKF = lambda x: (x - 273.15) * 1.8 + 32
temps4 = temps3.apply(convKF)
temps4.columns = ['T (F)',  'Lo STDV (F)',  'Hi STDV (F)']
temps4.head()
# Out:
#                                T (F)  Lo STDV (F)  Hi STDV (F)
# 2013-07-19 09:00:00+00:00  70.268007    68.468007    72.068007
# 2013-07-19 10:00:00+00:00  68.365999    66.505999    70.225999
# 2013-07-19 11:00:00+00:00  66.463990    64.543990    68.383991
# 2013-07-19 12:00:00+00:00  64.561982    62.581982    66.541982
# 2013-07-19 13:00:00+00:00  64.861982    62.161982    67.561982

# %% [markdown]
# ## Now let's plot

# %%
ax = temps4.plot(color = 'b')
ax.fill_between(temps4.index,temps4['Lo STDV (F)'],temps4['Hi STDV (F)'], alpha=0.4, color='r')

# %% [markdown]
# ## Pandas has powerful data slicing and dicing capability.

# %% [markdown]
# ### I prefer to exercise when the temperature is less than 80 F during "daylight hours".
# - Select temperatures
# - Convert the time zone to local time
# - Constrain data between times.

# %%
# Selecting temps < 80
temps5 = temps4[temps4['T (F)'] < 80]
# Convert to local time zone
temps6 = temps5.tz_convert('US/Mountain')
# Delimit day light hours
temps6.between_time('5:00', '20:00')
# Out:
#                                T (F)  Lo STDV (F)  Hi STDV (F)
# 2013-07-19 05:00:00-06:00  66.463990    64.543990    68.383991
# 2013-07-19 06:00:00-06:00  64.561982    62.581982    66.541982
# 2013-07-19 07:00:00-06:00  64.861982    62.161982    67.561982
# 2013-07-19 08:00:00-06:00  65.161982    61.741982    68.581982
# 2013-07-19 09:00:00-06:00  65.461982    61.321983    69.601982
# 2013-07-19 10:00:00-06:00  66.439985    61.759985    71.119985
# 2013-07-19 11:00:00-06:00  67.417988    62.197988    72.637988
# 2013-07-19 12:00:00-06:00  68.395991    62.635991    74.155991
# 2013-07-19 13:00:00-06:00  70.099989    64.399989    75.799989
# 2013-07-19 14:00:00-06:00  71.803987    66.163987    77.443987
# 2013-07-19 15:00:00-06:00  73.507985    67.927985    79.087984
# 2013-07-19 16:00:00-06:00  73.735988    68.635988    78.835987
# 2013-07-19 17:00:00-06:00  73.963990    69.343991    78.583990
# 2013-07-19 18:00:00-06:00  74.191993    70.051993    78.331993
# 2013-07-19 19:00:00-06:00  71.594001    68.114001    75.074001
# 2013-07-19 20:00:00-06:00  68.996010    66.176009    71.816010
# 2013-07-20 05:00:00-06:00  59.612001    57.452001    61.772001
# 2013-07-20 06:00:00-06:00  59.072004    56.732004    61.412004
# 2013-07-20 07:00:00-06:00  64.082008    61.202008    66.962008
# 2013-07-20 08:00:00-06:00  69.092012    65.672012    72.512012
# 2013-07-20 09:00:00-06:00  74.102015    70.142015    78.062015
# 2013-07-20 10:00:00-06:00  77.528010    73.928010    81.128010
# 2013-07-20 19:00:00-06:00  79.441993    75.601993    83.281993
# 2013-07-20 20:00:00-06:00  75.926002    72.206002    79.646002
# 2013-07-21 05:00:00-06:00  60.925984    59.065984    62.785984
# 2013-07-21 06:00:00-06:00  59.719978    58.099978    61.339978
# 2013-07-21 07:00:00-06:00  64.543983    62.383983    66.703983
# 2013-07-21 08:00:00-06:00  69.367988    66.667988    72.067988
# 2013-07-21 09:00:00-06:00  74.191993    70.951993    77.431993
# 2013-07-21 10:00:00-06:00  78.080000    74.960000    81.200000
# 2013-07-21 20:00:00-06:00  77.672004    75.152004    80.192004
# 2013-07-22 05:00:00-06:00  60.662001    57.242001    64.082001
# 2013-07-22 06:00:00-06:00  59.683998    55.903998    63.463998
# 2013-07-22 07:00:00-06:00  66.523994    62.803994    70.243994
# 2013-07-22 08:00:00-06:00  73.363990    69.703991    77.023990

# %% [markdown]
# ### What are the minimum and maximum temperatures in the forthcoming days

# %%
# Group by day (as specified by lambda function) and aggregated by min and max
temps7 = temps4.groupby(temps4.index.map(lambda t: t.day)).agg([np.min, np.max])
# Removing distracting information
del temps7['Lo STDV (F)'] 
del temps7['Hi STDV (F)'] 
temps7
# Out:
#         T (F)
#          amin       amax
# 19  64.561982  73.963990
# 20  59.072004  87.836024
# 21  59.719978  88.465980
# 22  59.683998  89.941993

# %% [markdown]
# ## *Exercise*
#
# - Create a new notebook cell here.
# - Create a Pandas DataFrame containing one of the variables listed below
# - Hint: Print the Dataframe if you are having trouble finding your column.
# - Plot it

# %%
# Getting all variables from SREF

from netCDF4 import Dataset
from pyudl.tds import get_latest_dods_url

sref_data_url = \
    "http://thredds.ucar.edu/thredds/catalog/grib/NCEP/SREF/CONUS_40km/ensprod/files/catalog.xml"
latest = get_latest_dods_url(sref_data_url)
data = Dataset(latest)

for i in data.variables:
    print i
# Out:
# LambertConformal_Projection
# x
# y
# height_above_ground
# isobaric
# isobaric1
# pressure_difference_layer
# pressure_difference_layer_bounds
# isobaric2
# height_above_ground1
# time
# time1
# time1_bounds
# time2
# time2_bounds
# time3
# time3_bounds
# Temperature_isobaric_stdDev
# Temperature_isobaric_weightedMean
# Temperature_isobaric_probability_below_273
# Temperature_height_above_ground_weightedMean
# Temperature_height_above_ground_stdDev
# Temperature_height_above_ground_probability_below_273
# Dewpoint_temperature_isobaric_weightedMean
# Dewpoint_temperature_isobaric_stdDev
# Dewpoint_temperature_height_above_ground_weightedMean
# Dewpoint_temperature_height_above_ground_stdDev
# Precipitable_water_entire_atmosphere_weightedMean
# Precipitable_water_entire_atmosphere_stdDev
# Total_precipitation_surface_3_Hour_Accumulation_weightedMean
# Total_precipitation_surface_3_Hour_Accumulation_probability_above_0p25
# Total_precipitation_surface_3_Hour_Accumulation_stdDev
# Total_precipitation_surface_3_Hour_Accumulation_probability_above_6p35
# Total_precipitation_surface_3_Hour_Accumulation_probability_above_12p7
# Total_precipitation_surface_3_Hour_Accumulation_probability_above_25p4
# Total_precipitation_surface_12_Hour_Accumulation_probability_above_50p8
# Large-scale_snow_surface_12_Hour_Accumulation_probability_above_304p8
# Large-scale_snow_surface_12_Hour_Accumulation_stdDev
# Large-scale_snow_surface_12_Hour_Accumulation_probability_above_101p6
# Large-scale_snow_surface_12_Hour_Accumulation_weightedMean
# Large-scale_snow_surface_12_Hour_Accumulation_probability_above_25p4
# Large-scale_snow_surface_12_Hour_Accumulation_probability_above_203p2
# Categorical_Rain_surface_probability_equals_1
# Categorical_Freezing_Rain_surface_probability_equals_1
# Categorical_Ice_Pellets_surface_probability_equals_1
# Categorical_Snow_surface_probability_equals_1
# Wind_speed_isobaric_stdDev
# Wind_speed_height_above_ground_probability_above_25p78
# Wind_speed_height_above_ground_stdDev
# Wind_speed_height_above_ground_probability_above_12p89
# Wind_speed_height_above_ground_probability_above_17p5
# u-component_of_wind_isobaric_weightedMean
# u-component_of_wind_height_above_ground_weightedMean
# v-component_of_wind_isobaric_weightedMean
# v-component_of_wind_height_above_ground_weightedMean
# Pressure_reduced_to_MSL_msl_weightedMean
# Pressure_reduced_to_MSL_msl_stdDev
# Geopotential_height_isobaric_weightedMean
# Geopotential_height_isobaric_stdDev
# Geopotential_height_cloud_ceiling_probability_below_305
# Geopotential_height_cloud_ceiling_probability_below_152p5
# Geopotential_height_cloud_ceiling_probability_below_914p6
# Parcel_lifted_index_to_500_hPa_pressure_difference_layer_probability_below_-8
# Parcel_lifted_index_to_500_hPa_pressure_difference_layer_probability_below_0
# Parcel_lifted_index_to_500_hPa_pressure_difference_layer_probability_below_-4
# Convective_available_potential_energy_surface_probability_above_500
# Convective_available_potential_energy_surface_probability_above_4000
# Convective_available_potential_energy_surface_probability_above_3000
# Convective_available_potential_energy_surface_probability_above_2000
# Convective_available_potential_energy_surface_probability_above_1000
# Visibility_surface_probability_below_4827
# Visibility_surface_probability_below_1609
