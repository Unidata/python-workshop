# %% [markdown]
# # Exploring THREDDS netCDF Subset Service (NCSS) with Pandas
# - NCSS is a web service for subsetting CDM scientific datasets.
# - NCSS can return CSV format which works well with Pandas.
#
# ## Pandas
# - Pandas is a highly popular data analysis library for Python (think, R, SQL, Excel, etc.).
# - Built on top of Numpy
#
# ## Let's explore some Short Range Ensemble Forecast (SREF) data from the TDS
# - Build the NCSS URL parameters.
# - Request CSV data
# - Read data into a "Pandas DataFrame" object

# %%
import urllib
import datetime as dt
import string
import pandas as pd
import numpy as np
# base THREDDS URL from which we will request our data
ncss_url = "http://thredds.ucar.edu/thredds/ncss/grib/NCEP/SREF/CONUS_40km/ensprod_biasc/Best"

# Forming our date range
start_time = dt.datetime.utcnow() - dt.timedelta(hours = 12)

# Construct the URL parameters requesting CSV point data
parameters = (('var', 'Temperature_height_above_ground_weightedMean'), 
     ('var', 'Temperature_height_above_ground_stdDev'), 
     ('latitude', 40.044385),
     ('longitude', -105.21928),
     ('time_start', start_time.strftime("%Y-%m-%dT%H")),
     ('time_duration', 'P3DT12H'),
     ('accept','csv'),
     ('point', 'true'))

# prepping the URL parameters
params = urllib.urlencode(parameters)

# join the base URL with the parameters
url = string.join([ncss_url, params], '?')
print("Our fully constructed URL...\n")
print(url)
# Out:
# Our fully constructed URL...
#
# http://thredds.ucar.edu/thredds/ncss/grib/NCEP/SREF/CONUS_40km/ensprod_biasc/Best?var=Temperature_height_above_ground_weightedMean&var=Temperature_height_above_ground_stdDev&latitude=40.044385&longitude=-105.21928&time_start=2014-09-11T00&time_duration=P3DT12H&accept=csv&point=true

# %% [markdown]
# ## Pandas DataFrame
# - A spreadsheet-like data structure

# %%
# This cell continued from previous Python cell

# Reading remote data into a pandas data frame
# The first argument is the URL we constructed above.
# Subsequent arguments below deal with parsing the date time
# Indexing with datetime
df  = pd.read_csv(url,  parse_dates={'datetime':['date']}, date_parser=
    lambda x: dt.datetime.strptime( x, '%Y-%m-%dT%H:%M:%SZ'), index_col='datetime')

# Constructing a time series with time as the index, and associating temperature
# and temperature STDV to that index
temps = df.ix[:, [3,4]]
print(temps.head())
# Out:
#                      Temperature_height_above_ground_weightedMean[unit="K"]  \
# datetime
# 2014-09-11 00:00:00                                         294.140015
# 2014-09-11 03:00:00                                         287.899994
# 2014-09-11 06:00:00                                         286.049988
# 2014-09-11 09:00:00                                         281.579987
# 2014-09-11 12:00:00                                         280.670013
#
#                      Temperature_height_above_ground_stdDev[unit="K"]
# datetime
# 2014-09-11 00:00:00                                               1.2
# 2014-09-11 03:00:00                                               1.4
# 2014-09-11 06:00:00                                               0.7
# 2014-09-11 09:00:00                                               0.7
# 2014-09-11 12:00:00                                               1.0

# %% [markdown]
# ## Let's make the columns nicer.

# %%
# Renaming columns to something more convenient
temps.columns = ['T (K)', 'T STDV (K)']
# Let's localize the time zone for good measure
temps = temps.tz_localize('UTC')
# Printing only the top of the data frame
temps.head()
# Out:
#                                 T (K)  T STDV (K)
# datetime
# 2014-09-11 00:00:00+00:00  294.140015         1.2
# 2014-09-11 03:00:00+00:00  287.899994         1.4
# 2014-09-11 06:00:00+00:00  286.049988         0.7
# 2014-09-11 09:00:00+00:00  281.579987         0.7
# 2014-09-11 12:00:00+00:00  280.670013         1.0

# %% [markdown]
# ## Let's prepare the data for plotting

# %%
# Calculate the high and low standard deviation
temps['Lo STDV (K)'] = temps['T (K)'] - temps['T STDV (K)']
temps['Hi STDV (K)'] = temps['T (K)'] + temps['T STDV (K)']

# Pandas dataframes are *mutable*, therefore deep copy
temps2 = temps.copy()

# Getting rid of stdv column to make things simpler below 
del temps2['T STDV (K)']
temps2.head()
# Out:
#                                 T (K)  Lo STDV (K)  Hi STDV (K)
# datetime
# 2014-09-11 00:00:00+00:00  294.140015   292.940015   295.340015
# 2014-09-11 03:00:00+00:00  287.899994   286.499994   289.299994
# 2014-09-11 06:00:00+00:00  286.049988   285.349988   286.749988
# 2014-09-11 09:00:00+00:00  281.579987   280.879987   282.279987
# 2014-09-11 12:00:00+00:00  280.670013   279.670013   281.670013

# %% [markdown]
# ## Let's resample the data to one hourly data

# %%
# First convert to 1 hourly data
temps3 = temps2.asfreq('1H')
print(temps3.head())
# Apply interpolation function to converted data
temps3 = temps3.apply(pd.Series.interpolate)
temps3.head()
# Out:
#                                 T (K)  Lo STDV (K)  Hi STDV (K)
# 2014-09-11 00:00:00+00:00  294.140015   292.940015   295.340015
# 2014-09-11 01:00:00+00:00         NaN          NaN          NaN
# 2014-09-11 02:00:00+00:00         NaN          NaN          NaN
# 2014-09-11 03:00:00+00:00  287.899994   286.499994   289.299994
# 2014-09-11 04:00:00+00:00         NaN          NaN          NaN
#                                 T (K)  Lo STDV (K)  Hi STDV (K)
# 2014-09-11 00:00:00+00:00  294.140015   292.940015   295.340015
# 2014-09-11 01:00:00+00:00  292.060008   290.793341   293.326674
# 2014-09-11 02:00:00+00:00  289.980001   288.646667   291.313334
# 2014-09-11 03:00:00+00:00  287.899994   286.499994   289.299994
# 2014-09-11 04:00:00+00:00  287.283325   286.116659   288.449992

# %% [markdown]
# ## Convert from Kelvin to Fahrenheit
# - Remember to change the units in the column names.

# %%
convKF = lambda x: (x - 273.15) * 1.8 + 32
temps4 = temps3.apply(convKF)
temps4.columns = ['T (F)',  'Lo STDV (F)',  'Hi STDV (F)']
temps4.head()
# Out:
#                                T (F)  Lo STDV (F)  Hi STDV (F)
# 2014-09-11 00:00:00+00:00  69.782026    67.622026    71.942026
# 2014-09-11 01:00:00+00:00  66.038014    63.758014    68.318014
# 2014-09-11 02:00:00+00:00  62.294001    59.894001    64.694001
# 2014-09-11 03:00:00+00:00  58.549989    56.029989    61.069989
# 2014-09-11 04:00:00+00:00  57.439985    55.339985    59.539985

# %% [markdown]
# ## Now let's plot

# %%
ax = temps4.plot(color = 'b')
ax.fill_between(temps4.index,temps4['Lo STDV (F)'],temps4['Hi STDV (F)'], alpha=0.4, color='r')

# %% [markdown]
# ## Pandas has powerful data slicing and dicing capability.

# %% [markdown]
# ### I prefer to exercise when the temperature is less than 80 F during "daylight hours".
# - Select temperatures
# - Convert the time zone to local time
# - Constrain data between times.

# %%
# Selecting temps < 80
temps5 = temps4[temps4['T (F)'] < 80]
# Convert to local time zone
temps6 = temps5.tz_convert('US/Mountain')
# Delimit day light hours
temps6.between_time('5:00', '20:00')
# Out:
#                                T (F)  Lo STDV (F)  Hi STDV (F)
# 2014-09-10 18:00:00-06:00  69.782026    67.622026    71.942026
# 2014-09-10 19:00:00-06:00  66.038014    63.758014    68.318014
# 2014-09-10 20:00:00-06:00  62.294001    59.894001    64.694001
# 2014-09-11 05:00:00-06:00  46.082008    44.462008    47.702008
# 2014-09-11 06:00:00-06:00  45.536024    43.736024    47.336024
# 2014-09-11 07:00:00-06:00  48.344020    45.044020    51.644020
# 2014-09-11 08:00:00-06:00  51.152015    46.352015    55.952015
# 2014-09-11 09:00:00-06:00  53.960011    47.660011    60.260011
# 2014-09-11 10:00:00-06:00  56.858003    49.058003    64.658003
# 2014-09-11 11:00:00-06:00  59.755995    50.455995    69.055995
# 2014-09-11 12:00:00-06:00  62.653987    51.853987    73.453987
# 2014-09-11 13:00:00-06:00  60.289985    49.129985    71.449985
# 2014-09-11 14:00:00-06:00  57.925984    46.405984    69.445984
# 2014-09-11 15:00:00-06:00  55.561982    43.681983    67.441982
# 2014-09-11 16:00:00-06:00  48.271986    37.291986    59.251986
# 2014-09-11 17:00:00-06:00  40.981990    30.901990    51.061990
# 2014-09-11 18:00:00-06:00  33.691993    24.511994    42.871993
# 2014-09-11 19:00:00-06:00  34.094001    26.534002    41.654001
# 2014-09-11 20:00:00-06:00  34.496010    28.556009    40.436010
# 2014-09-12 05:00:00-06:00  34.105995    32.305995    35.905995
# 2014-09-12 06:00:00-06:00  33.637996    32.017996    35.257996
# 2014-09-12 07:00:00-06:00  33.463990    32.023990    34.903990
# 2014-09-12 08:00:00-06:00  33.289985    32.029985    34.549985
# 2014-09-12 09:00:00-06:00  33.115980    32.035980    34.195980
# 2014-09-12 10:00:00-06:00  35.173994    33.793994    36.553994
# 2014-09-12 11:00:00-06:00  37.232008    35.552008    38.912008
# 2014-09-12 12:00:00-06:00  39.290022    37.310022    41.270022
# 2014-09-12 13:00:00-06:00  42.644020    40.304020    44.984020
# 2014-09-12 14:00:00-06:00  45.998018    43.298018    48.698018
# 2014-09-12 15:00:00-06:00  49.352015    46.292015    52.412015
# 2014-09-12 16:00:00-06:00  48.464009    45.404009    51.524009
# 2014-09-12 17:00:00-06:00  47.576002    44.516002    50.636002
# 2014-09-12 18:00:00-06:00  46.687996    43.627996    49.747996
# 2014-09-12 19:00:00-06:00  44.876002    41.936002    47.816002
# 2014-09-12 20:00:00-06:00  43.064009    40.244009    45.884009
# 2014-09-13 05:00:00-06:00  34.652015    32.792015    36.512015
# 2014-09-13 06:00:00-06:00  35.348018    33.548018    37.148018
# 2014-09-13 07:00:00-06:00  38.576021    36.476021    40.676021
# 2014-09-13 08:00:00-06:00  41.804023    39.404023    44.204023
# 2014-09-13 09:00:00-06:00  45.032026    42.332026    47.732026
# 2014-09-13 10:00:00-06:00  53.738014    50.978014    56.498014
# 2014-09-13 11:00:00-06:00  62.444001    59.624001    65.264001
# 2014-09-13 12:00:00-06:00  71.149989    68.269989    74.029989
# 2014-09-13 13:00:00-06:00  69.133998    66.133998    72.133998
# 2014-09-13 14:00:00-06:00  67.118007    63.998007    70.238007
# 2014-09-13 15:00:00-06:00  65.102015    61.862015    68.342015
# 2014-09-13 16:00:00-06:00  64.526002    61.046002    68.006002
# 2014-09-13 17:00:00-06:00  63.949989    60.229989    67.669989
# 2014-09-13 18:00:00-06:00  63.373976    59.413976    67.333976
# 2014-09-13 19:00:00-06:00  61.435988    57.595987    65.275988
# 2014-09-13 20:00:00-06:00  59.497999    55.777999    63.217999
# 2014-09-14 05:00:00-06:00  45.626002    41.666002    49.586002
# 2014-09-14 06:00:00-06:00  41.576002    37.616002    45.536002

# %% [markdown]
# ### What are the minimum and maximum temperatures in the forthcoming days

# %%
# Group by day (as specified by lambda function) and aggregated by min and max
temps7 = temps4.groupby(temps4.index.map(lambda t: t.day)).agg([np.min, np.max])
# Removing distracting information
del temps7['Lo STDV (F)'] 
del temps7['Hi STDV (F)'] 
temps7
# Out:
#         T (F)
#          amin       amax
# 11  40.981990  69.782026
# 12  33.115980  49.352015
# 13  33.260011  71.149989
# 14  41.576002  63.373976

# %% [markdown]
# ## *Exercise*
#
# - Create a new notebook cell here.
# - Create a Pandas DataFrame containing one of the variables listed below
# - Hint: Print the Dataframe if you are having trouble finding your column.
# - Plot it

# %%
# Getting all variables from SREF

from netCDF4 import Dataset
from pyudl.tds import get_latest_dods_url

sref_data_url = \
    "http://thredds.ucar.edu/thredds/catalog/grib/NCEP/SREF/CONUS_40km/ensprod_biasc/catalog.xml"
latest = get_latest_dods_url(sref_data_url)
data = Dataset(latest)

for i in data.variables:
    print i
# Out:
# LambertConformal_Projection
# reftime_ISO
# time_bounds
# isobaric_layer_bounds
# x
# y
# reftime
# time
# time1
# isobaric
# height_above_ground
# height_above_ground1
# isobaric_layer
# isobaric1
# isobaric2
# Geopotential_height_isobaric_stdDev
# Geopotential_height_isobaric_layer_stdDev
# Geopotential_height_isobaric_weightedMean
# Geopotential_height_isobaric_layer_weightedMean
# Pressure_reduced_to_MSL_msl_weightedMean
# Pressure_reduced_to_MSL_msl_stdDev
# Relative_humidity_isobaric_weightedMean
# Relative_humidity_isobaric_stdDev
# Relative_humidity_height_above_ground_weightedMean
# Relative_humidity_height_above_ground_stdDev
# Specific_humidity_height_above_ground_weightedMean
# Specific_humidity_height_above_ground_stdDev
# Temperature_height_above_ground_probability_below_273
# Temperature_height_above_ground_weightedMean
# Temperature_height_above_ground_stdDev
# Temperature_isobaric_probability_below_273
# Temperature_isobaric_stdDev
# Temperature_isobaric_weightedMean
# Total_precipitation_surface_3_Hour_Accumulation
# Wind_speed_isobaric_weightedMean
# Wind_speed_isobaric_stdDev
# Wind_speed_height_above_ground_probability_above_12p89
# Wind_speed_height_above_ground_probability_above_17p5
# Wind_speed_height_above_ground_weightedMean
# Wind_speed_height_above_ground_stdDev
# Wind_speed_height_above_ground_probability_above_25p78
# u-component_of_wind_height_above_ground_stdDev
# u-component_of_wind_height_above_ground_weightedMean
# u-component_of_wind_isobaric_stdDev
# u-component_of_wind_isobaric_weightedMean
# v-component_of_wind_isobaric_stdDev
# v-component_of_wind_isobaric_weightedMean
# v-component_of_wind_height_above_ground_stdDev
# v-component_of_wind_height_above_ground_weightedMean
