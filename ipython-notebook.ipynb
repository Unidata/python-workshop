# %% [markdown]
# # ipython notebook**"The most significant development in scientific computing in the last decade." -Dr. C. Titus Brown, MSU*** ipython notebook is an interactive web environment for running and annotating  python code* ipython notebook gives the output as it is generated* very powerful for quickly experimenting with codeand accelerating the learning curve* typically ipython notebook runs on your local machine, but can be run remotely or on the cloud (e.g. EC2)

# %% [markdown]
# ## Starting ipython notebook    ipython notebook --pylab inline* `pylab` bundles some scientific computing libraries together* `inline` enables embedded figures in the notebook

# %% [markdown]
# ## Hello worldNote that the cells can be edited and re-run with shift-enter.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Embedding MarkdownYou can embed your notebok with markdown. Markdown is a very lightweight web markup language can be inserted right into the notebook. This is very useful for annotating your notebook code samples.

# %% [markdown]
# ## Nice Errors

# %%
1 + foo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/chastang/git/tds-python-workshop/<ipython-input-3-130777adf3f0> in <module>()
# ----> 1 1 + foo
#
# NameError: name 'foo' is not defined

# %% [markdown]
# ## Inline DocumentationExecuting the cell will split the pane and open documentation.

# %%
open?

# %% [markdown]
# ## Tab CompletionType tab after `o` and see what happens. You should see a pop-up dropdown menu of choices.

# %%
o

# %% [markdown]
# ## HelpCheck out "QuickHelp" button at the top for lots of useful tips. Learn the keyboard shortcuts to save lots of time.

# %% [markdown]
# ## Plottingipython notebook has nice *inline* plotting capability.

# %%
# Lissajous curvefrom numpy import sin,pi,linspacefrom pylab import plot,show,subplotdelta = pi/2t = linspace(-pi,pi,300)x = sin(3 * t + delta)y = sin(5 * t)plot(x,y)show()

# %% [markdown]
# ## InterruptsIf ipython get jammed up, you can restart it with the `Interrupt` and `Restart` buttons.

# %% [markdown]
# ## LaTeX     $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$yields:$$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %% [markdown]
# ## Run Shell Commands with `!`

# %%
# !ls
# Out:
# README.md              ipython-notebook.ipynb numpy.ipynb

# %% [markdown]
# ## Local or Remote Images and Even Videos

# %%
from IPython.core.display import Image Image('http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif" />

# %% [markdown]
# ## Load External Codes

# %% [markdown]
# ## Take Python Code and Display it in LaTeX (Wow!)

# %%
# %load_ext sympyprintingimport sympy as symfrom sympy import *x, y, z = sym.symbols("x y z")eq = ((x+y)**2 * (x+1))eq
# Out:
#                2(x + 1)⋅(x + y)

# %% [markdown]
# ## Load External Codes

# %%
loadpy http://matplotlib.org/mpl_examples/pylab_examples/simple_plot.py

# %%
from pylab import *t = arange(0.0, 2.0, 0.01)s = sin(2*pi*t)plot(t, s, linewidth=1.0)xlabel('time (s)')ylabel('voltage (mV)')title('About as simple as it gets, folks')grid(True)savefig("test.png")show()
