# %% [markdown]
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://raw.githubusercontent.com/Unidata/MetPy/master/metpy/plots/_static/unidata_150x150.png" alt="Unidata Logo" style="height: 98px;">
# </div>
#
# <h1>Unidata Python Workshop</h1>
# <h3>Table of Contents</h3>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# Welcome to the Unidata Python Workshop! This notebook contains links to course content and other useful materials.

# %% [markdown]
# <div style="float:left">
# <center>
# <h3>Workshop Contents</h3>
# </center>
# <table>
#   <tr>
#     <th>Topic</th>
#     <th></th>
#     <th></th>
#   </tr>
#   <tr>
#     <td>Git</td>
#     <td><a href="../presentations/git.md">Notes</a></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Conda</td>
#     <td><a href="../presentations/conda.md">Notes</a></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="Jupyter_Notebooks">Jupyter Notebooks</a></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="Primer">Primer</a></td>
#     <td><a href="Primer/Primer.ipynb">Lesson</a></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="Time_Series">Time_Series</a></td>
#     <td><a href="Time_Series/Time Series Plotting.ipynb">Lesson</a></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="Skew_T">Skew-T</a></td>
#     <td><a href="Skew_T/Upper Air and the Skew-T Log-P.ipynb">Lesson</a></td>
#     <td><a href="Skew_T/Upper Air and the Skew-T Log-P Exercises.ipynb">Exercises</a></td>
#   </tr>
#   <tr>
#     <td><a href="Surface_Data">Surface Data</a></td>
#     <td><a href="Surface_Data/Surface Data with Siphon and Metpy.ipynb">Lesson</a></td>
#     <td><a href="Surface_Data/Surface Data Exercises.ipynb">Exercises</a></td>
#   </tr>
#   <tr>
#     <td><a href="Satellite_Data">Satellite Data</a></td>
#     <td><a href="Satellite_Data/Working with Satellite Data.ipynb">Lesson</a></td>
#     <td><a href="Satellite_Data/Working with Satellite Data Exercises.ipynb"></a></td>
#   </tr>
#   <tr>
#     <td><a href="Model_Data">Model Data</a></td>
#     <td><a href="Model_Data/Siphon_Cartopy_MetPy_HRRR.ipynb">Lesson</a></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="Command_Line_Tools">Command Line Tools</a></td>
#     <td><a href="Command_Line_Tools/Command_Line_Primer.ipynb">Slides</a></td>
#     <td></td>
#   </tr>
# </table>
# </div>
#
# <div style="float:left; padding:0px 20px">
# <center>
# <h3>Extra Content</h3>
# </center>
# <table>
#   <tr>
#     <th>Topic</th>
#     <th></th>
#     <th></th>
#   </tr>
#   <tr>
#     <td><a href="Bonus">Bonus Examples</a></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="GOES_RGB_Demo">GOES RGB Demo</a></td>
#     <td><a href="GOES_RGB_Demo/GOES_RGB_Image.ipynb">Demo</a></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="netCDF">netCDF</a></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="python-awips">AWIPS</a></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td><a href="Pythonic_Data_Analysis">Pythonic Data Analysis</a></td>
#     <td><a href="Pythonic_Data_Analysis/pythonic-data-analysis.ipynb">Lesson</a></td>
#     <td><a href="Pythonic_Data_Analysis/pythonic-data-analysis-solution.ipynb">Solution</a></td>
#   </tr>
# </table>
# </div>
#
# <div style="float:left; padding:0px 0px">
# <center>
# <h3>Links</h3>
# </center>
# <ul>
# <li><a href="https://unidata.github.io/unidata-python-workshop/">Workshop Webpage</a></li>
# <li><a href="https://github.com/Unidata/unidata-python-workshop">Workshop GitHub Repository</a></li>
# </ul>
# </div>
