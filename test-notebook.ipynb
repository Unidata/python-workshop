# %% [markdown]
# ipython notebook test

# %%
import numpy as npimport matplotlib.pyplot as pltx = np.arange(0,100.5,0.5) # Generate x-axis valuesy = 2.0*np.sqrt(x)  # Calculate y-valuesplt.plot(x,y)   # Create figure and axis objectsplt.show()  # Display plot to screen
