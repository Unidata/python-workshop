# %%
import xray
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
URL = 'http://thredds.ucar.edu/thredds/dodsC/grib/NCEP/GFS/Global_0p5deg/Best'

# %%
ds = xray.open_dataset(URL)

# %%
# select lat,lon region of interest
# note: slice(20.5,55.0) fails
dsloc = ds.sel(lon=slice(230.5,300.0),lat=slice(55.0,20.5))

# %%
# select closest data to time of interest
date = datetime.datetime(2015,7,15,3,0,0)
#date = datetime.datetime.now()
ds_snapshot = dsloc.sel(time=date,time1=date,time2=date,method='nearest')

# %%
# ds.data_vars
# ds.coords
# ds.attrs

# %%
t = ds_snapshot['Temperature_surface']

# %%
t.shape
# Out:
# (70, 140)

# %%
plt.pcolormesh(t.lon.data,t.lat.data,t.data)
plt.title(t.name+pd.Timestamp(t.time.values).strftime(': %Y-%m-%d  %H:%M:%S %Z %z'));

# %%
# time series closest to specified lon,lat location
ds_series = ds.sel(lon=250.,lat=33.,method='nearest')

# %%
# Select temperature and convert to Pandas Series
v_series = ds_series['Temperature_surface'].to_series()

# %%
v_series.plot(title=v_series.name);

# %%
ds_snapshot.to_netcdf('ds_snapshot.nc')

# %%
ds_snapshot
# Out:
# <xray.Dataset>
# Dimensions:                                                                     (altitude_above_msl: 3, depth_below_surface_layer: 4, depth_below_surface_layer_bounds_1: 2, height_above_ground: 1, height_above_ground1: 2, height_above_ground2: 1, height_above_ground3: 3, height_above_ground4: 3, height_above_ground_layer: 1, height_above_ground_layer1: 1, height_above_ground_layer1_bounds_1: 2, height_above_ground_layer_bounds_1: 2, isobaric: 12, isobaric1: 1, isobaric2: 21, isobaric3: 26, lat: 70, lon: 140, potential_vorticity_surface: 2, pressure_difference_layer: 1, pressure_difference_layer1: 1, pressure_difference_layer1_bounds_1: 2, pressure_difference_layer2: 2, pressure_difference_layer2_bounds_1: 2, pressure_difference_layer_bounds_1: 2, sigma: 1, sigma_layer: 4, sigma_layer_bounds_1: 2, time2_bounds_1: 2)
# Coordinates:
#   * lat                                                                         (lat) float32 55.0 ...
#   * lon                                                                         (lon) float32 230.5 ...
#     time                                                                        datetime64[ns] 2015-07-15T03:00:00 ...
#     reftime                                                                     datetime64[ns] 2015-07-15 ...
#     time1                                                                       datetime64[ns] 2015-07-15T03:00:00 ...
#     reftime1                                                                    datetime64[ns] 2015-07-15 ...
#     time2                                                                       datetime64[ns] 2015-07-15T03:00:00 ...
#     reftime2                                                                    datetime64[ns] 2015-07-15 ...
#   * depth_below_surface_layer                                                   (depth_below_surface_layer) float32 0.05 ...
#   * isobaric                                                                    (isobaric) float32 1000.0 ...
#   * height_above_ground_layer                                                   (height_above_ground_layer) float32 1500.0 ...
#   * height_above_ground                                                         (height_above_ground) float32 2.0 ...
#   * potential_vorticity_surface                                                 (potential_vorticity_surface) float32 -2e-06 ...
#   * pressure_difference_layer                                                   (pressure_difference_layer) float32 1500.0 ...
#   * isobaric1                                                                   (isobaric1) float32 50000.0 ...
#   * height_above_ground1                                                        (height_above_ground1) float32 2.0 ...
#   * height_above_ground2                                                        (height_above_ground2) float32 80.0 ...
#   * isobaric2                                                                   (isobaric2) float32 10000.0 ...
#   * sigma                                                                       (sigma) float32 0.995 ...
#   * altitude_above_msl                                                          (altitude_above_msl) float32 1829.0 ...
#   * height_above_ground3                                                        (height_above_ground3) float32 10.0 ...
#   * height_above_ground_layer1                                                  (height_above_ground_layer1) float32 3000.0 ...
#   * pressure_difference_layer1                                                  (pressure_difference_layer1) float32 12750.0 ...
#   * isobaric3                                                                   (isobaric3) float32 1000.0 ...
#   * sigma_layer                                                                 (sigma_layer) float32 0.58 ...
#   * pressure_difference_layer2                                                  (pressure_difference_layer2) float32 9000.0 ...
#   * height_above_ground4                                                        (height_above_ground4) float32 2.0 ...
#   * depth_below_surface_layer_bounds_1                                          (depth_below_surface_layer_bounds_1) int64 0 ...
#   * height_above_ground_layer1_bounds_1                                         (height_above_ground_layer1_bounds_1) int64 0 ...
#   * height_above_ground_layer_bounds_1                                          (height_above_ground_layer_bounds_1) int64 0 ...
#   * pressure_difference_layer1_bounds_1                                         (pressure_difference_layer1_bounds_1) int64 0 ...
#   * pressure_difference_layer2_bounds_1                                         (pressure_difference_layer2_bounds_1) int64 0 ...
#   * pressure_difference_layer_bounds_1                                          (pressure_difference_layer_bounds_1) int64 0 ...
#   * sigma_layer_bounds_1                                                        (sigma_layer_bounds_1) int64 0 ...
#   * time2_bounds_1                                                              (time2_bounds_1) int64 0 ...
# Data variables:
#     LatLon_Projection                                                           int32 0 ...
#     time2_bounds                                                                (time2_bounds_1) datetime64[ns] 2015-07-15 ...
#     depth_below_surface_layer_bounds                                            (depth_below_surface_layer, depth_below_surface_layer_bounds_1) float32 0.0 ...
#     height_above_ground_layer_bounds                                            (height_above_ground_layer, height_above_ground_layer_bounds_1) float32 3000.0 ...
#     pressure_difference_layer_bounds                                            (pressure_difference_layer, pressure_difference_layer_bounds_1) float32 3000.0 ...
#     height_above_ground_layer1_bounds                                           (height_above_ground_layer1, height_above_ground_layer1_bounds_1) float32 6000.0 ...
#     pressure_difference_layer1_bounds                                           (pressure_difference_layer1, pressure_difference_layer1_bounds_1) float32 25500.0 ...
#     sigma_layer_bounds                                                          (sigma_layer, sigma_layer_bounds_1) float32 0.44 ...
#     pressure_difference_layer2_bounds                                           (pressure_difference_layer2, pressure_difference_layer2_bounds_1) float32 18000.0 ...
#     Total_ozone_entire_atmosphere_single_layer                                  (lat, lon) float32 349.2 ...
#     Ozone_Mixing_Ratio_isobaric                                                 (isobaric, lat, lon) float32 1.2478e-05 ...
#     Momentum_flux_u-component_surface_Mixed_intervals_Average                   (lat, lon) float32 -0.011 ...
#     Momentum_flux_v-component_surface_Mixed_intervals_Average                   (lat, lon) float32 -0.095 ...
#     Surface_Lifted_Index_surface                                                (lat, lon) float32 3.7 ...
#     Downward_Short-Wave_Radiation_Flux_surface_Mixed_intervals_Average          (lat, lon) float32 83.0 ...
#     Downward_Long-Wave_Radp_Flux_surface_Mixed_intervals_Average                (lat, lon) float32 349.0 ...
#     MSLP_Eta_model_reduction_msl                                                (lat, lon) float32 101430.0 ...
#     Pressure_high_cloud_bottom_Mixed_intervals_Average                          (lat, lon) float32 41310.0 ...
#     Pressure_low_cloud_bottom_Mixed_intervals_Average                           (lat, lon) float32 88350.0 ...
#     Pressure_low_cloud_top_Mixed_intervals_Average                              (lat, lon) float32 68180.0 ...
#     Pressure_high_cloud_top_Mixed_intervals_Average                             (lat, lon) float32 23840.4 ...
#     Vertical_Speed_Shear_potential_vorticity_surface                            (potential_vorticity_surface, lat, lon) float32 nan ...
#     Pressure_middle_cloud_top_Mixed_intervals_Average                           (lat, lon) float32 51080.0 ...
#     Pressure_middle_cloud_bottom_Mixed_intervals_Average                        (lat, lon) float32 68160.0 ...
#     Ventilation_Rate_planetary_boundary                                         (lat, lon) float32 1000.0 ...
#     Pressure_convective_cloud_top                                               (lat, lon) float32 nan ...
#     Pressure_convective_cloud_bottom                                            (lat, lon) float32 nan ...
#     Vertical_Speed_Shear_tropopause                                             (lat, lon) float32 -0.0012 ...
#     Wind_speed_gust_surface                                                     (lat, lon) float32 3.0 ...
#     Pressure_of_level_from_which_parcel_was_lifted_pressure_difference_layer    (pressure_difference_layer1, lat, lon) float32 93563.2 ...
#     Temperature_low_cloud_top_Mixed_intervals_Average                           (lat, lon) float32 269.1 ...
#     Temperature_middle_cloud_top_Mixed_intervals_Average                        (lat, lon) float32 256.9 ...
#     Temperature_high_cloud_top_Mixed_intervals_Average                          (lat, lon) float32 218.3 ...
#     Categorical_Rain_surface_Mixed_intervals_Average                            (lat, lon) float32 1.0 ...
#     Potential_Evaporation_Rate_surface                                          (lat, lon) float32 99.0 ...
#     Volumetric_Soil_Moisture_Content_depth_below_surface_layer                  (depth_below_surface_layer, lat, lon) float32 0.278 ...
#     Ice_cover_surface                                                           (lat, lon) float32 0.0 ...
#     Land_cover_0__sea_1__land_surface                                           (lat, lon) float32 1.0 ...
#     Pressure_surface                                                            (lat, lon) float32 93813.3 ...
#     Specific_humidity_pressure_difference_layer                                 (pressure_difference_layer, lat, lon) float32 0.007219 ...
#     Temperature_pressure_difference_layer                                       (pressure_difference_layer, lat, lon) float32 282.9 ...
#     Temperature_surface                                                         (lat, lon) float32 283.7 ...
#     Albedo_surface_Mixed_intervals_Average                                      (lat, lon) float32 16.4 ...
#     Relative_humidity_sigma_layer                                               (sigma_layer, lat, lon) float32 96.0 ...
#     Relative_humidity_pressure_difference_layer                                 (pressure_difference_layer, lat, lon) float32 88.0 ...
#     Haines_Index_surface                                                        (lat, lon) float32 3.0 ...
#     Soil_temperature_depth_below_surface_layer                                  (depth_below_surface_layer, lat, lon) float32 284.7 ...
#     u-component_of_wind_pressure_difference_layer                               (pressure_difference_layer, lat, lon) float32 1.15 ...
#     v-component_of_wind_pressure_difference_layer                               (pressure_difference_layer, lat, lon) float32 2.53 ...
#     Geopotential_height_surface                                                 (lat, lon) float32 656.161 ...
#     Water_runoff_surface_Mixed_intervals_Accumulation                           (lat, lon) float32 0.1312 ...
#     Convective_available_potential_energy_pressure_difference_layer             (pressure_difference_layer2, lat, lon) float32 3.0 ...
#     Convective_available_potential_energy_surface                               (lat, lon) float32 18.0 ...
#     Convective_inhibition_pressure_difference_layer                             (pressure_difference_layer2, lat, lon) float32 0.0 ...
#     Convective_inhibition_surface                                               (lat, lon) float32 -1.0 ...
#     Precipitation_rate_surface_Mixed_intervals_Average                          (lat, lon) float32 9e-05 ...
#     Storm_relative_helicity_height_above_ground_layer                           (height_above_ground_layer, lat, lon) float32 95.0 ...
#     Total_precipitation_surface_Mixed_intervals_Accumulation                    (lat, lon) float32 0.9 ...
#     Convective_precipitation_surface_Mixed_intervals_Accumulation               (lat, lon) float32 0.01 ...
#     Latent_heat_net_flux_surface_Mixed_intervals_Average                        (lat, lon) float32 48.0 ...
#     Sensible_heat_net_flux_surface_Mixed_intervals_Average                      (lat, lon) float32 8.0 ...
#     Snow_depth_surface                                                          (lat, lon) float32 0.0 ...
#     Water_equivalent_of_accumulated_snow_depth_surface                          (lat, lon) float32 0.0 ...
#     Total_cloud_cover_high_cloud_Mixed_intervals_Average                        (lat, lon) float32 83.0 ...
#     Total_cloud_cover_convective_cloud                                          (lat, lon) float32 0.0 ...
#     Total_cloud_cover_low_cloud_Mixed_intervals_Average                         (lat, lon) float32 88.0 ...
#     Total_cloud_cover_middle_cloud_Mixed_intervals_Average                      (lat, lon) float32 97.0 ...
#     Total_cloud_cover_boundary_layer_cloud_Mixed_intervals_Average              (lat, lon) float32 6.0 ...
#     Cloud_Work_Function_entire_atmosphere_single_layer_Mixed_intervals_Average  (lat, lon) float32 0.0 ...
#     Sunshine_Duration_surface                                                   (lat, lon) float32 9509.0 ...
#     Best_4_layer_Lifted_Index_surface                                           (lat, lon) float32 4.0 ...
#     Upward_Short-Wave_Radiation_Flux_atmosphere_top_Mixed_intervals_Average     (lat, lon) float32 392.0 ...
#     Upward_Short-Wave_Radiation_Flux_surface_Mixed_intervals_Average            (lat, lon) float32 14.0 ...
#     Upward_Long-Wave_Radp_Flux_surface_Mixed_intervals_Average                  (lat, lon) float32 371.0 ...
#     Upward_Long-Wave_Radp_Flux_atmosphere_top_Mixed_intervals_Average           (lat, lon) float32 194.0 ...
#     5-Wave_Geopotential_Height_isobaric                                         (isobaric1, lat, lon) float32 5752.85 ...
#     Relative_humidity_highest_tropospheric_freezing                             (lat, lon) float32 98.0 ...
#     Relative_humidity_entire_atmosphere_single_layer                            (lat, lon) float32 34.0 ...
#     Categorical_Freezing_Rain_surface_Mixed_intervals_Average                   (lat, lon) float32 0.0 ...
#     Ground_Heat_Flux_surface_Mixed_intervals_Average                            (lat, lon) float32 2.0 ...
#     Wilting_Point_surface                                                       (lat, lon) float32 0.0469 ...
#     Per_cent_frozen_precipitation_surface                                       (lat, lon) float32 -50.0 ...
#     Temperature_isobaric                                                        (isobaric3, lat, lon) float32 240.1 ...
#     Relative_humidity_isobaric                                                  (isobaric3, lat, lon) float32 0.0 ...
#     Relative_humidity_zeroDegC_isotherm                                         (lat, lon) float32 98.0 ...
#     u-component_of_wind_isobaric                                                (isobaric3, lat, lon) float32 -11.0 ...
#     v-component_of_wind_isobaric                                                (isobaric3, lat, lon) float32 0.2 ...
#     Geopotential_height_isobaric                                                (isobaric3, lat, lon) float32 31876.3 ...
#     Geopotential_height_zeroDegC_isotherm                                       (lat, lon) float32 2396.32 ...
#     U-Component_Storm_Motion_height_above_ground_layer                          (height_above_ground_layer1, lat, lon) float32 10.41 ...
#     Zonal_Flux_of_Gravity_Wave_Stress_surface_Mixed_intervals_Average           (lat, lon) float32 1.721 ...
#     u-component_of_wind_planetary_boundary                                      (lat, lon) float32 1.1 ...
#     Categorical_Ice_Pellets_surface_Mixed_intervals_Average                     (lat, lon) float32 0.0 ...
#     Vertical_velocity_pressure_isobaric                                         (isobaric2, lat, lon) float32 0.00832891 ...
#     Absolute_vorticity_isobaric                                                 (isobaric3, lat, lon) float32 0.0001115 ...
#     Pressure_reduced_to_MSL_msl                                                 (lat, lon) float32 101432.0 ...
#     Cloud_mixing_ratio_isobaric                                                 (isobaric2, lat, lon) float32 0.0 ...
#     Pressure_maximum_wind                                                       (lat, lon) float32 26917.8 ...
#     Temperature_altitude_above_msl                                              (altitude_above_msl, lat, lon) float32 276.5 ...
#     Temperature_maximum_wind                                                    (lat, lon) float32 221.0 ...
#     u-component_of_wind_altitude_above_msl                                      (altitude_above_msl, lat, lon) float32 2.89 ...
#     u-component_of_wind_maximum_wind                                            (lat, lon) float32 7.1 ...
#     ICAO_Standard_Atmosphere_Reference_Height_maximum_wind                      (lat, lon) float32 9881.79 ...
#     v-component_of_wind_altitude_above_msl                                      (altitude_above_msl, lat, lon) float32 4.87 ...
#     v-component_of_wind_maximum_wind                                            (lat, lon) float32 15.4 ...
#     Apparent_temperature_height_above_ground                                    (height_above_ground, lat, lon) float32 283.8 ...
#     Geopotential_height_maximum_wind                                            (lat, lon) float32 9951.07 ...
#     V-Component_Storm_Motion_height_above_ground_layer                          (height_above_ground_layer1, lat, lon) float32 3.12 ...
#     Meridional_Flux_of_Gravity_Wave_Stress_surface_Mixed_intervals_Average      (lat, lon) float32 0.447 ...
#     Field_Capacity_surface                                                      (lat, lon) float32 0.2821 ...
#     v-component_of_wind_planetary_boundary                                      (lat, lon) float32 2.5 ...
#     Precipitable_water_entire_atmosphere_single_layer                           (lat, lon) float32 20.9 ...
#     Categorical_Snow_surface_Mixed_intervals_Average                            (lat, lon) float32 0.0 ...
#     Pressure_height_above_ground                                                (height_above_ground2, lat, lon) float32 92921.3 ...
#     Pressure_tropopause                                                         (lat, lon) float32 25387.3 ...
#     Specific_humidity_height_above_ground                                       (height_above_ground1, lat, lon) float32 0.00778 ...
#     Temperature_tropopause                                                      (lat, lon) float32 219.3 ...
#     Temperature_height_above_ground                                             (height_above_ground4, lat, lon) float32 283.8 ...
#     Relative_humidity_height_above_ground                                       (height_above_ground, lat, lon) float32 91.3 ...
#     u-component_of_wind_height_above_ground                                     (height_above_ground3, lat, lon) float32 0.62 ...
#     u-component_of_wind_tropopause                                              (lat, lon) float32 7.5 ...
#     ICAO_Standard_Atmosphere_Reference_Height_tropopause                        (lat, lon) float32 10263.5 ...
#     v-component_of_wind_height_above_ground                                     (height_above_ground3, lat, lon) float32 1.49 ...
#     v-component_of_wind_tropopause                                              (lat, lon) float32 14.8 ...
#     Maximum_temperature_height_above_ground_Mixed_intervals_Maximum             (height_above_ground, lat, lon) float32 285.1 ...
#     Geopotential_height_tropopause                                              (lat, lon) float32 10328.0 ...
#     Minimum_temperature_height_above_ground_Mixed_intervals_Minimum             (height_above_ground, lat, lon) float32 283.8 ...
#     Dewpoint_temperature_height_above_ground                                    (height_above_ground, lat, lon) float32 282.4 ...
#     Temperature_sigma                                                           (sigma, lat, lon) float32 283.7 ...
#     Relative_humidity_sigma                                                     (sigma, lat, lon) float32 87.0 ...
#     Potential_temperature_sigma                                                 (sigma, lat, lon) float32 289.4 ...
#     u-component_of_wind_sigma                                                   (sigma, lat, lon) float32 1.05 ...
#     v-component_of_wind_sigma                                                   (sigma, lat, lon) float32 1.85 ...
#     Planetary_Boundary_Layer_Height_surface                                     (lat, lon) float32 300.04 ...
#     Convective_Precipitation_Rate_surface_Mixed_intervals_Average               (lat, lon) float32 1e-06 ...
#     Vertical_velocity_pressure_sigma                                            (sigma, lat, lon) float32 0.04 ...
#     Total_cloud_cover_entire_atmosphere_Mixed_intervals_Average                 (lat, lon) float32 100.0 ...
#     Geopotential_height_highest_tropospheric_freezing                           (lat, lon) float32 2396.64 ...
#     Cloud_water_entire_atmosphere_single_layer                                  (lat, lon) float32 0.48 ...
#     Pressure_potential_vorticity_surface                                        (potential_vorticity_surface, lat, lon) float32 nan ...
#     Temperature_potential_vorticity_surface                                     (potential_vorticity_surface, lat, lon) float32 nan ...
#     u-component_of_wind_potential_vorticity_surface                             (potential_vorticity_surface, lat, lon) float32 nan ...
#     v-component_of_wind_potential_vorticity_surface                             (potential_vorticity_surface, lat, lon) float32 nan ...
#     Geopotential_height_potential_vorticity_surface                             (potential_vorticity_surface, lat, lon) float32 nan ...
# Attributes:
#     Originating_or_generating_Center: US National Weather Service, National Centres for Environmental Prediction (NCEP)
#     Originating_or_generating_Subcenter: 0
#     GRIB_table_version: 2,1
#     Type_of_generating_process: Forecast
#     Analysis_or_forecast_generating_process_identifier_defined_by_originating_centre: Analysis from GFS (Global Forecast System)
#     file_format: GRIB-2
#     Conventions: CF-1.6
#     history: Read using CDM IOSP GribCollection v3
#     featureType: GRID
#     _CoordSysBuilder: ucar.nc2.dataset.conv.CF1Convention

# %%
# !ls -sh ds_snapshot.nc
# Out:
# 15M ds_snapshot.nc
